# %% [markdown]
# # EfficientNet

# %%
import os
import cv2
import pydicom
import numpy as np
import pandas as pd
import seaborn as sns
import tensorflow as tf
import matplotlib.pyplot as plt
from tqdm.notebook import tqdm

# %% [markdown]
# # Load and Transform Data

# %%
train = pd.read_csv('D:/CSE499/osic-pulmonary-fibrosis-progression/train.csv')

# %%
train.head()
# Out:
#                      Patient  Weeks   FVC    Percent  Age   Sex SmokingStatus
# 0  ID00007637202177411956430     -4  2315  58.253649   79  Male     Ex-smoker
# 1  ID00007637202177411956430      5  2214  55.712129   79  Male     Ex-smoker
# 2  ID00007637202177411956430      7  2061  51.862104   79  Male     Ex-smoker
# 3  ID00007637202177411956430      9  2144  53.950679   79  Male     Ex-smoker
# 4  ID00007637202177411956430     11  2069  52.063412   79  Male     Ex-smoker

# %%
train.SmokingStatus.unique()
# Out:
# array(['Ex-smoker', 'Never smoked', 'Currently smokes'], dtype=object)

# %%
def get_tab(df):
    "raturn an array which contains each patient normalized age, sex and smoking status"
    vector = [(df.Age.values[0] - 30) / 30] 
    
    if df.Sex.values[0].lower() == 'male':
       vector.append(0)
    else:
       vector.append(1)
    
    if df.SmokingStatus.values[0] == 'Never smoked':
        vector.extend([0,0])
    elif df.SmokingStatus.values[0] == 'Ex-smoker':
        vector.extend([1,1])
    elif df.SmokingStatus.values[0] == 'Currently smokes':
        vector.extend([0,1])
    else:
        vector.extend([1,0])
    return np.array(vector)

# %%
A = {} 
TAB = {} 
P = [] 
for i, p in tqdm(enumerate(train.Patient.unique())): # i index, p patient id
    sub = train.loc[train.Patient == p, :] # find all data (weeks, FVC, Percent, Age, Sex, SmokingStatus) of a unique patient
    fvc = sub.FVC.values # fvc values of the patient during the follow-up
    weeks = sub.Weeks.values # follow-up weeks
    c = np.vstack([weeks, np.ones(len(weeks))]).T # create an array by the follow-up weeks of shape(len(weeks),2)
    a, b = np.linalg.lstsq(c, fvc)[0] # least-square sol, a=gradient matrix, b=right hand matrix 
    
    A[p] = a
    TAB[p] = get_tab(sub)
    P.append(p)
# Out:
# HBox(children=(HTML(value=''), FloatProgress(value=1.0, bar_style='info', layout=Layout(width='20px'), max=1.0…
# C:\Users\Monir\anaconda3\envs\rabbi36\lib\site-packages\ipykernel_launcher.py:9: FutureWarning: `rcond` parameter will change to the default of machine precision times ``max(M, N)`` where M and N are the input matrix dimensions.
# To use the future default and silence this warning we advise to pass `rcond=None`, to keep using the old, explicitly pass `rcond=-1`.
#   if __name__ == '__main__':

# %%
def get_img(path):
    "read DICOM dataset and return resize images of size (512,512,1)"
    d = pydicom.dcmread(path) # read and parse the CT scan images (in DICOM format)
    resized_image = cv2.resize((d.pixel_array - d.RescaleIntercept) / (d.RescaleSlope * 1000), (512,512))
    return resized_image

# %%
from tensorflow.keras.utils import Sequence

class IGenerator(Sequence):
    BAD_ID = ['ID00011637202177653955184', 'ID00052637202186188008618']
    def __init__(self, keys, a, tab, batch_size):
        "key=patient, a=gradient matrix, tab=a particular patient's data"
        self.keys = [k for k in keys if k not in self.BAD_ID]
        self.a = a
        self.tab = tab
        self.batch_size = batch_size
        
        self.train_data = {}
        for p in train.Patient.values:
            self.train_data[p] = os.listdir(f'D:/CSE499/osic-pulmonary-fibrosis-progression/train/{p}/')
    
    def __len__(self):
        return 1000
    
    def __getitem__(self, idx):
        x = []
        a, tab = [], [] 
        keys = np.random.choice(self.keys, size = self.batch_size) # randomly chooses n=batch_size number of patients
        for k in keys:
            try:
                i = np.random.choice(self.train_data[k], size=1)[0] # chooses some randomly images for kth patient
                img = get_img(f'D:/CSE499/osic-pulmonary-fibrosis-progression/train/{k}/{i}') # resizes ith image of kth patient
                x.append(img) # append kth patient's image data in the list x
                a.append(self.a[k]) # append kth patient's gradinet in the list a
                tab.append(self.tab[k]) # append kth patient's tabular data in the tab list
            except:
                print(k, i)
       
        x,a,tab = np.array(x), np.array(a), np.array(tab) # convert list to array
        x = np.expand_dims(x, axis=-1) 
        return [x, tab] , a

# %% [markdown]
# ## Build the Model

# %%
from tensorflow.keras import Model
from tensorflow.keras.layers import (
    Dense, Dropout, Activation, Flatten, Input, BatchNormalization, GlobalAveragePooling2D, GaussianNoise, 
    Add, Conv2D, AveragePooling2D, LeakyReLU, Concatenate 
)

# %%
import efficientnet.tfkeras as efn

def get_efficientnet(model, shape):
    models_dict = {
        'b0': efn.EfficientNetB0(input_shape=shape,weights=None,include_top=False),
        'b1': efn.EfficientNetB1(input_shape=shape,weights=None,include_top=False),
        'b2': efn.EfficientNetB2(input_shape=shape,weights=None,include_top=False),
        'b3': efn.EfficientNetB3(input_shape=shape,weights=None,include_top=False),
        'b4': efn.EfficientNetB4(input_shape=shape,weights=None,include_top=False),
        'b5': efn.EfficientNetB5(input_shape=shape,weights=None,include_top=False),
        'b6': efn.EfficientNetB6(input_shape=shape,weights=None,include_top=False),
        'b7': efn.EfficientNetB7(input_shape=shape,weights=None,include_top=False)
    }
    return models_dict[model]

def build_model(shape=(512, 512, 1), model_class=None):
    inp = Input(shape=shape)
    base = get_efficientnet(model_class, shape)
    x = base(inp)
    x = GlobalAveragePooling2D()(x)
    inp2 = Input(shape=(4,)) # indicates that the expected input will be batches of 4-dimensional vectors
    x2 = GaussianNoise(0.2)(inp2) # to mitigate overfitting
    x = Concatenate()([x, x2]) 
    x = Dropout(0.5)(x) 
    x = Dense(1)(x)
    model = Model([inp, inp2] , x)
    return model

# %%
MODEL_CLASS = 'b2'
base_model = build_model(shape=(512, 512, 1), model_class=MODEL_CLASS)
base_model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 512, 512, 1) 0
# __________________________________________________________________________________________________
# efficientnet-b2 (Model)         (None, 16, 16, 1408) 7767986     input_1[0][0]
# __________________________________________________________________________________________________
# input_10 (InputLayer)           [(None, 4)]          0
# __________________________________________________________________________________________________
# global_average_pooling2d (Globa (None, 1408)         0           efficientnet-b2[1][0]
# __________________________________________________________________________________________________
# gaussian_noise (GaussianNoise)  (None, 4)            0           input_10[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 1412)         0           global_average_pooling2d[0][0]
#                                                                  gaussian_noise[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 1412)         0           concatenate[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 1)            1413        dropout[0][0]
# ==================================================================================================
# Total params: 7,769,399
# Trainable params: 7,701,831
# Non-trainable params: 67,568
# __________________________________________________________________________________________________

# %% [markdown]
# ## Compile and Train the Model

# %%
BATCH_SIZE = 1
EPOCHS = 80
LR = 0.001
SAVE_BEST = True

# %%
P = np.array(P)
subs = []
folds_history = []

"""
er = tf.keras.callbacks.EarlyStopping(monitor="val_loss",min_delta=1e-3,patience=15,verbose=1,mode="auto",baseline=None,
      restore_best_weights=True,) #Stop training when a monitored metric has stopped improving.
"""

cpt = tf.keras.callbacks.ModelCheckpoint(filepath=f'C:/Users/Monir/Documents/CSE499/models/EfficientNet/{MODEL_CLASS}_{EPOCHS}_epochs.h5',monitor='val_loss',verbose=1, 
    save_best_only=SAVE_BEST,mode='auto') #to save model or weights in a checkpoint file at lowest validation loss

rlp = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss',factor=0.5,patience=5, verbose=1, min_lr=1e-8) 
     #Reduce learning rate when a metric has stopped improving.
     # if improvement stops, after 5 epochs learning rate will be reduced

model = build_model(model_class=MODEL_CLASS)
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=LR), loss="mae") 
history = model.fit(IGenerator(keys=P, a = A, tab = TAB, batch_size=BATCH_SIZE), 
                    steps_per_epoch = 32,
                    validation_data=IGenerator(keys=P, a = A, tab = TAB, batch_size=BATCH_SIZE),
                    validation_steps = 32, 
                    callbacks = [cpt, rlp], 
                    epochs=EPOCHS)
folds_history.append(history.history)
print('Training Complete!!!')
# Out:
# Epoch 1/80
# 32/32 [==============================] - ETA: 0s - loss: 3.8254
# Epoch 00001: val_loss improved from inf to 4.40477, saving model to C:/Users/Monir/Documents/CSE499/models/EfficientNet/b2_80_epochs.h5
# 32/32 [==============================] - 6s 189ms/step - loss: 3.8254 - val_loss: 4.4048 - lr: 0.0010
# Epoch 2/80
# 32/32 [==============================] - ETA: 0s - loss: 4.6731
# Epoch 00002: val_loss did not improve from 4.40477
# 32/32 [==============================] - 3s 109ms/step - loss: 4.6731 - val_loss: 11.3936 - lr: 0.0010
# Epoch 3/80
# 32/32 [==============================] - ETA: 0s - loss: 6.3825
# Epoch 00003: val_loss improved from 4.40477 to 3.84352, saving model to C:/Users/Monir/Documents/CSE499/models/EfficientNet/b2_80_epochs.h5
# 32/32 [==============================] - 8s 250ms/step - loss: 6.3825 - val_loss: 3.8435 - lr: 0.0010
# Epoch 4/80
# 32/32 [==============================] - ETA: 0s - loss: 5.0982
# Epoch 00004: val_loss did not improve from 3.84352
# 32/32 [==============================] - 4s 132ms/step - loss: 5.0982 - val_loss: 12.4765 - lr: 0.0010
# Epoch 5/80
# 32/32 [==============================] - ETA: 0s - loss: 2.2033
# Epoch 00005: val_loss did not improve from 3.84352
# 32/32 [==============================] - 3s 106ms/step - loss: 2.2033 - val_loss: 12.3028 - lr: 0.0010
# Epoch 6/80
# 32/32 [==============================] - ETA: 0s - loss: 4.2943
# Epoch 00006: val_loss did not improve from 3.84352
# 32/32 [==============================] - 4s 111ms/step - loss: 4.2943 - val_loss: 78.1682 - lr: 0.0010
# Epoch 7/80
# 32/32 [==============================] - ETA: 0s - loss: 5.2613
# Epoch 00007: val_loss did not improve from 3.84352
# 32/32 [==============================] - 4s 110ms/step - loss: 5.2613 - val_loss: 18.3515 - lr: 0.0010
# Epoch 8/80
# 32/32 [==============================] - ETA: 0s - loss: 4.8808
# Epoch 00008: val_loss did not improve from 3.84352
#
# Epoch 00008: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 32/32 [==============================] - 3s 108ms/step - loss: 4.8808 - val_loss: 24.8255 - lr: 0.0010
# Epoch 9/80
# 32/32 [==============================] - ETA: 0s - loss: 3.7259
# Epoch 00009: val_loss did not improve from 3.84352
# 32/32 [==============================] - 3s 109ms/step - loss: 3.7259 - val_loss: 8.2474 - lr: 5.0000e-04
# Epoch 10/80
# 32/32 [==============================] - ETA: 0s - loss: 4.4651
# Epoch 00010: val_loss did not improve from 3.84352
# 32/32 [==============================] - 3s 104ms/step - loss: 4.4651 - val_loss: 11.4307 - lr: 5.0000e-04
# Epoch 11/80
# 32/32 [==============================] - ETA: 0s - loss: 5.0078
# Epoch 00011: val_loss did not improve from 3.84352
# 32/32 [==============================] - 4s 109ms/step - loss: 5.0078 - val_loss: 10.6795 - lr: 5.0000e-04
# Epoch 12/80
# 32/32 [==============================] - ETA: 0s - loss: 4.1475
# Epoch 00012: val_loss did not improve from 3.84352
# 32/32 [==============================] - 4s 117ms/step - loss: 4.1475 - val_loss: 17.6565 - lr: 5.0000e-04
# Epoch 13/80
# 32/32 [==============================] - ETA: 0s - loss: 4.0640
# Epoch 00013: val_loss did not improve from 3.84352
#
# Epoch 00013: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 32/32 [==============================] - 4s 113ms/step - loss: 4.0640 - val_loss: 16.2214 - lr: 5.0000e-04
# Epoch 14/80
# 32/32 [==============================] - ETA: 0s - loss: 3.1332
# Epoch 00014: val_loss did not improve from 3.84352
# 32/32 [==============================] - 3s 109ms/step - loss: 3.1332 - val_loss: 29.3134 - lr: 2.5000e-04
# Epoch 15/80
# 32/32 [==============================] - ETA: 0s - loss: 4.8157
# Epoch 00015: val_loss did not improve from 3.84352
# 32/32 [==============================] - 4s 112ms/step - loss: 4.8157 - val_loss: 45.5555 - lr: 2.5000e-04
# Epoch 16/80
# 32/32 [==============================] - ETA: 0s - loss: 2.6754
# Epoch 00016: val_loss did not improve from 3.84352
# 32/32 [==============================] - 3s 106ms/step - loss: 2.6754 - val_loss: 53.3874 - lr: 2.5000e-04
# Epoch 17/80
# 32/32 [==============================] - ETA: 0s - loss: 4.0144
# Epoch 00017: val_loss did not improve from 3.84352
# 32/32 [==============================] - 3s 103ms/step - loss: 4.0144 - val_loss: 28.0637 - lr: 2.5000e-04
# Epoch 18/80
# 32/32 [==============================] - ETA: 0s - loss: 4.2409
# Epoch 00018: val_loss did not improve from 3.84352
#
# Epoch 00018: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 32/32 [==============================] - 3s 106ms/step - loss: 4.2409 - val_loss: 21.7406 - lr: 2.5000e-04
# Epoch 19/80
# 32/32 [==============================] - ETA: 0s - loss: 3.5788
# Epoch 00019: val_loss did not improve from 3.84352
# 32/32 [==============================] - 3s 106ms/step - loss: 3.5788 - val_loss: 22.1530 - lr: 1.2500e-04
# Epoch 20/80
# 32/32 [==============================] - ETA: 0s - loss: 4.8416
# Epoch 00020: val_loss did not improve from 3.84352
# 32/32 [==============================] - 3s 107ms/step - loss: 4.8416 - val_loss: 21.3878 - lr: 1.2500e-04
# Epoch 21/80
# 32/32 [==============================] - ETA: 0s - loss: 3.5450
# Epoch 00021: val_loss did not improve from 3.84352
# 32/32 [==============================] - 3s 107ms/step - loss: 3.5450 - val_loss: 27.8803 - lr: 1.2500e-04
# Epoch 22/80
# 32/32 [==============================] - ETA: 0s - loss: 4.2206
# Epoch 00022: val_loss did not improve from 3.84352
# 32/32 [==============================] - 3s 104ms/step - loss: 4.2206 - val_loss: 28.8418 - lr: 1.2500e-04
# Epoch 23/80
# 32/32 [==============================] - ETA: 0s - loss: 4.4064
# Epoch 00023: val_loss did not improve from 3.84352
#
# Epoch 00023: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 32/32 [==============================] - 3s 107ms/step - loss: 4.4064 - val_loss: 42.7340 - lr: 1.2500e-04
# Epoch 24/80
# 32/32 [==============================] - ETA: 0s - loss: 3.9753
# Epoch 00024: val_loss did not improve from 3.84352
# 32/32 [==============================] - 3s 108ms/step - loss: 3.9753 - val_loss: 43.7903 - lr: 6.2500e-05
# Epoch 25/80
# 32/32 [==============================] - ETA: 0s - loss: 4.4456
# Epoch 00025: val_loss did not improve from 3.84352
# 32/32 [==============================] - 3s 105ms/step - loss: 4.4456 - val_loss: 39.0445 - lr: 6.2500e-05
# Epoch 26/80
# 32/32 [==============================] - ETA: 0s - loss: 5.9215
# Epoch 00026: val_loss did not improve from 3.84352
# 32/32 [==============================] - 3s 105ms/step - loss: 5.9215 - val_loss: 44.3293 - lr: 6.2500e-05
# Epoch 27/80
# 32/32 [==============================] - ETA: 0s - loss: 3.9053
# Epoch 00027: val_loss did not improve from 3.84352
# 32/32 [==============================] - 3s 107ms/step - loss: 3.9053 - val_loss: 39.8812 - lr: 6.2500e-05
# Epoch 28/80
# 32/32 [==============================] - ETA: 0s - loss: 4.6700
# Epoch 00028: val_loss did not improve from 3.84352
#
# Epoch 00028: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 32/32 [==============================] - 3s 105ms/step - loss: 4.6700 - val_loss: 56.5886 - lr: 6.2500e-05
# Epoch 29/80
# 32/32 [==============================] - ETA: 0s - loss: 4.6042
# Epoch 00029: val_loss did not improve from 3.84352
# 32/32 [==============================] - 3s 104ms/step - loss: 4.6042 - val_loss: 62.4297 - lr: 3.1250e-05
# Epoch 30/80
# 32/32 [==============================] - ETA: 0s - loss: 5.2011
# Epoch 00030: val_loss did not improve from 3.84352
# 32/32 [==============================] - 3s 103ms/step - loss: 5.2011 - val_loss: 37.1505 - lr: 3.1250e-05
# Epoch 31/80
# 32/32 [==============================] - ETA: 0s - loss: 4.3349
# Epoch 00031: val_loss did not improve from 3.84352
# 32/32 [==============================] - 3s 105ms/step - loss: 4.3349 - val_loss: 45.0176 - lr: 3.1250e-05
# Epoch 32/80
# 32/32 [==============================] - ETA: 0s - loss: 4.6657
# Epoch 00032: val_loss did not improve from 3.84352
# 32/32 [==============================] - 3s 105ms/step - loss: 4.6657 - val_loss: 30.8164 - lr: 3.1250e-05
# Epoch 33/80
# 32/32 [==============================] - ETA: 0s - loss: 3.5459
# Epoch 00033: val_loss did not improve from 3.84352
#
# Epoch 00033: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 32/32 [==============================] - 3s 106ms/step - loss: 3.5459 - val_loss: 24.4164 - lr: 3.1250e-05
# Epoch 34/80
# 32/32 [==============================] - ETA: 0s - loss: 3.0994
# Epoch 00034: val_loss did not improve from 3.84352
# 32/32 [==============================] - 3s 105ms/step - loss: 3.0994 - val_loss: 29.3331 - lr: 1.5625e-05
# Epoch 35/80
# 32/32 [==============================] - ETA: 0s - loss: 4.6734
# Epoch 00035: val_loss did not improve from 3.84352
# 32/32 [==============================] - 3s 106ms/step - loss: 4.6734 - val_loss: 30.8401 - lr: 1.5625e-05
# Epoch 36/80
# 32/32 [==============================] - ETA: 0s - loss: 3.5386
# Epoch 00036: val_loss did not improve from 3.84352
# 32/32 [==============================] - 3s 106ms/step - loss: 3.5386 - val_loss: 24.9628 - lr: 1.5625e-05
# Epoch 37/80
# 32/32 [==============================] - ETA: 0s - loss: 4.6702
# Epoch 00037: val_loss did not improve from 3.84352
# 32/32 [==============================] - 3s 104ms/step - loss: 4.6702 - val_loss: 31.7281 - lr: 1.5625e-05
# Epoch 38/80
# 32/32 [==============================] - ETA: 0s - loss: 2.3637
# Epoch 00038: val_loss did not improve from 3.84352
#
# Epoch 00038: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
# 32/32 [==============================] - 3s 105ms/step - loss: 2.3637 - val_loss: 58.9231 - lr: 1.5625e-05
# Epoch 39/80
# 32/32 [==============================] - ETA: 0s - loss: 5.3743
# Epoch 00039: val_loss did not improve from 3.84352
# 32/32 [==============================] - 3s 102ms/step - loss: 5.3743 - val_loss: 51.5298 - lr: 7.8125e-06
# Epoch 40/80
# 32/32 [==============================] - ETA: 0s - loss: 4.6825
# Epoch 00040: val_loss did not improve from 3.84352
# 32/32 [==============================] - 4s 110ms/step - loss: 4.6825 - val_loss: 49.8731 - lr: 7.8125e-06
# Epoch 41/80
# 32/32 [==============================] - ETA: 0s - loss: 4.5507
# Epoch 00041: val_loss did not improve from 3.84352
# 32/32 [==============================] - 3s 103ms/step - loss: 4.5507 - val_loss: 51.1243 - lr: 7.8125e-06
# Epoch 42/80
# 32/32 [==============================] - ETA: 0s - loss: 3.5877
# Epoch 00042: val_loss did not improve from 3.84352
# 32/32 [==============================] - 3s 104ms/step - loss: 3.5877 - val_loss: 48.4248 - lr: 7.8125e-06
# Epoch 43/80
# 32/32 [==============================] - ETA: 0s - loss: 4.4200
# Epoch 00043: val_loss did not improve from 3.84352
#
# Epoch 00043: ReduceLROnPlateau reducing learning rate to 3.906250185536919e-06.
# 32/32 [==============================] - 3s 103ms/step - loss: 4.4200 - val_loss: 43.3892 - lr: 7.8125e-06
# Epoch 44/80
# 32/32 [==============================] - ETA: 0s - loss: 4.4786
# Epoch 00044: val_loss did not improve from 3.84352
# 32/32 [==============================] - 3s 103ms/step - loss: 4.4786 - val_loss: 40.7383 - lr: 3.9063e-06
# Epoch 45/80
# 32/32 [==============================] - ETA: 0s - loss: 5.1139
# Epoch 00045: val_loss did not improve from 3.84352
# 32/32 [==============================] - 3s 106ms/step - loss: 5.1139 - val_loss: 40.6363 - lr: 3.9063e-06
# Epoch 46/80
# 32/32 [==============================] - ETA: 0s - loss: 5.0576
# Epoch 00046: val_loss did not improve from 3.84352
# 32/32 [==============================] - 3s 105ms/step - loss: 5.0576 - val_loss: 41.5721 - lr: 3.9063e-06
# Epoch 47/80
# 32/32 [==============================] - ETA: 0s - loss: 4.9887
# Epoch 00047: val_loss did not improve from 3.84352
# 32/32 [==============================] - 3s 104ms/step - loss: 4.9887 - val_loss: 49.6468 - lr: 3.9063e-06
# Epoch 48/80
# 32/32 [==============================] - ETA: 0s - loss: 3.6060
# Epoch 00048: val_loss did not improve from 3.84352
#
# Epoch 00048: ReduceLROnPlateau reducing learning rate to 1.9531250927684596e-06.
# 32/32 [==============================] - 3s 102ms/step - loss: 3.6060 - val_loss: 43.1470 - lr: 3.9063e-06
# Epoch 49/80
# 32/32 [==============================] - ETA: 0s - loss: 4.8924
# Epoch 00049: val_loss did not improve from 3.84352
# 32/32 [==============================] - 3s 102ms/step - loss: 4.8924 - val_loss: 69.1057 - lr: 1.9531e-06
# Epoch 50/80
# 32/32 [==============================] - ETA: 0s - loss: 5.5816
# Epoch 00050: val_loss did not improve from 3.84352
# 32/32 [==============================] - 3s 104ms/step - loss: 5.5816 - val_loss: 33.8192 - lr: 1.9531e-06
# Epoch 51/80
# 32/32 [==============================] - ETA: 0s - loss: 4.1126
# Epoch 00051: val_loss did not improve from 3.84352
# 32/32 [==============================] - 3s 104ms/step - loss: 4.1126 - val_loss: 34.2194 - lr: 1.9531e-06
# Epoch 52/80
# 32/32 [==============================] - ETA: 0s - loss: 3.7103
# Epoch 00052: val_loss did not improve from 3.84352
# 32/32 [==============================] - 3s 106ms/step - loss: 3.7103 - val_loss: 48.1311 - lr: 1.9531e-06
# Epoch 53/80
# 32/32 [==============================] - ETA: 0s - loss: 4.3777
# Epoch 00053: val_loss did not improve from 3.84352
#
# Epoch 00053: ReduceLROnPlateau reducing learning rate to 9.765625463842298e-07.
# 32/32 [==============================] - 3s 109ms/step - loss: 4.3777 - val_loss: 37.1560 - lr: 1.9531e-06
# Epoch 54/80
# 32/32 [==============================] - ETA: 0s - loss: 4.6705
# Epoch 00054: val_loss did not improve from 3.84352
# 32/32 [==============================] - 3s 105ms/step - loss: 4.6705 - val_loss: 46.3892 - lr: 9.7656e-07
# Epoch 55/80
# 32/32 [==============================] - ETA: 0s - loss: 4.7800
# Epoch 00055: val_loss did not improve from 3.84352
# 32/32 [==============================] - 3s 103ms/step - loss: 4.7800 - val_loss: 32.1758 - lr: 9.7656e-07
# Epoch 56/80
# 32/32 [==============================] - ETA: 0s - loss: 4.7337
# Epoch 00056: val_loss did not improve from 3.84352
# 32/32 [==============================] - 3s 103ms/step - loss: 4.7337 - val_loss: 45.7081 - lr: 9.7656e-07
# Epoch 57/80
# 32/32 [==============================] - ETA: 0s - loss: 5.0812
# Epoch 00057: val_loss did not improve from 3.84352
# 32/32 [==============================] - 3s 103ms/step - loss: 5.0812 - val_loss: 39.8146 - lr: 9.7656e-07
# Epoch 58/80
# 32/32 [==============================] - ETA: 0s - loss: 4.3374
# Epoch 00058: val_loss did not improve from 3.84352
#
# Epoch 00058: ReduceLROnPlateau reducing learning rate to 4.882812731921149e-07.
# 32/32 [==============================] - 3s 102ms/step - loss: 4.3374 - val_loss: 27.7869 - lr: 9.7656e-07
# Epoch 59/80
# 32/32 [==============================] - ETA: 0s - loss: 3.3354
# Epoch 00059: val_loss did not improve from 3.84352
# 32/32 [==============================] - 3s 105ms/step - loss: 3.3354 - val_loss: 24.5544 - lr: 4.8828e-07
# Epoch 60/80
# 32/32 [==============================] - ETA: 0s - loss: 4.3869
# Epoch 00060: val_loss did not improve from 3.84352
# 32/32 [==============================] - 3s 104ms/step - loss: 4.3869 - val_loss: 45.9795 - lr: 4.8828e-07
# Epoch 61/80
# 32/32 [==============================] - ETA: 0s - loss: 4.3793
# Epoch 00061: val_loss did not improve from 3.84352
# 32/32 [==============================] - 3s 104ms/step - loss: 4.3793 - val_loss: 82.2771 - lr: 4.8828e-07
# Epoch 62/80
# 32/32 [==============================] - ETA: 0s - loss: 4.5121
# Epoch 00062: val_loss did not improve from 3.84352
# 32/32 [==============================] - 3s 103ms/step - loss: 4.5121 - val_loss: 58.4427 - lr: 4.8828e-07
# Epoch 63/80
# 32/32 [==============================] - ETA: 0s - loss: 3.5020
# Epoch 00063: val_loss did not improve from 3.84352
#
# Epoch 00063: ReduceLROnPlateau reducing learning rate to 2.4414063659605745e-07.
# 32/32 [==============================] - 3s 103ms/step - loss: 3.5020 - val_loss: 58.9603 - lr: 4.8828e-07
# Epoch 64/80
# 32/32 [==============================] - ETA: 0s - loss: 4.7209
# Epoch 00064: val_loss did not improve from 3.84352
# 32/32 [==============================] - 3s 103ms/step - loss: 4.7209 - val_loss: 39.9040 - lr: 2.4414e-07
# Epoch 65/80
# 32/32 [==============================] - ETA: 0s - loss: 4.1992
# Epoch 00065: val_loss did not improve from 3.84352
# 32/32 [==============================] - 4s 112ms/step - loss: 4.1992 - val_loss: 68.9839 - lr: 2.4414e-07
# Epoch 66/80
# 32/32 [==============================] - ETA: 0s - loss: 3.6570
# Epoch 00066: val_loss did not improve from 3.84352
# 32/32 [==============================] - 4s 110ms/step - loss: 3.6570 - val_loss: 38.4918 - lr: 2.4414e-07
# Epoch 67/80
# 32/32 [==============================] - ETA: 0s - loss: 3.6032
# Epoch 00067: val_loss did not improve from 3.84352
# 32/32 [==============================] - 4s 119ms/step - loss: 3.6032 - val_loss: 43.9441 - lr: 2.4414e-07
# Epoch 68/80
# 32/32 [==============================] - ETA: 0s - loss: 3.9168
# Epoch 00068: val_loss did not improve from 3.84352
#
# Epoch 00068: ReduceLROnPlateau reducing learning rate to 1.2207031829802872e-07.
# 32/32 [==============================] - 4s 114ms/step - loss: 3.9168 - val_loss: 42.9383 - lr: 2.4414e-07
# Epoch 69/80
# 32/32 [==============================] - ETA: 0s - loss: 4.3221
# Epoch 00069: val_loss did not improve from 3.84352
# 32/32 [==============================] - 3s 109ms/step - loss: 4.3221 - val_loss: 33.6472 - lr: 1.2207e-07
# Epoch 70/80
# 32/32 [==============================] - ETA: 0s - loss: 5.3538
# Epoch 00070: val_loss did not improve from 3.84352
# 32/32 [==============================] - 3s 106ms/step - loss: 5.3538 - val_loss: 49.2688 - lr: 1.2207e-07
# Epoch 71/80
# 32/32 [==============================] - ETA: 0s - loss: 3.3706
# Epoch 00071: val_loss did not improve from 3.84352
# 32/32 [==============================] - 3s 107ms/step - loss: 3.3706 - val_loss: 38.9750 - lr: 1.2207e-07
# Epoch 72/80
# 32/32 [==============================] - ETA: 0s - loss: 4.9688
# Epoch 00072: val_loss did not improve from 3.84352
# 32/32 [==============================] - 4s 111ms/step - loss: 4.9688 - val_loss: 27.5821 - lr: 1.2207e-07
# Epoch 73/80
# 32/32 [==============================] - ETA: 0s - loss: 4.6962
# Epoch 00073: val_loss did not improve from 3.84352
#
# Epoch 00073: ReduceLROnPlateau reducing learning rate to 6.103515914901436e-08.
# 32/32 [==============================] - 4s 117ms/step - loss: 4.6962 - val_loss: 37.0566 - lr: 1.2207e-07
# Epoch 74/80
# 32/32 [==============================] - ETA: 0s - loss: 5.4408
# Epoch 00074: val_loss did not improve from 3.84352
# 32/32 [==============================] - 4s 118ms/step - loss: 5.4408 - val_loss: 31.9244 - lr: 6.1035e-08
# Epoch 75/80
# 32/32 [==============================] - ETA: 0s - loss: 3.8960
# Epoch 00075: val_loss did not improve from 3.84352
# 32/32 [==============================] - 4s 113ms/step - loss: 3.8960 - val_loss: 28.2061 - lr: 6.1035e-08
# Epoch 76/80
# 32/32 [==============================] - ETA: 0s - loss: 4.7441
# Epoch 00076: val_loss did not improve from 3.84352
# 32/32 [==============================] - 4s 115ms/step - loss: 4.7441 - val_loss: 37.4096 - lr: 6.1035e-08
# Epoch 77/80
# 32/32 [==============================] - ETA: 0s - loss: 6.0086
# Epoch 00077: val_loss did not improve from 3.84352
# 32/32 [==============================] - 4s 112ms/step - loss: 6.0086 - val_loss: 26.9753 - lr: 6.1035e-08
# Epoch 78/80
# 32/32 [==============================] - ETA: 0s - loss: 4.8199
# Epoch 00078: val_loss did not improve from 3.84352
#
# Epoch 00078: ReduceLROnPlateau reducing learning rate to 3.051757957450718e-08.
# 32/32 [==============================] - 4s 119ms/step - loss: 4.8199 - val_loss: 32.6898 - lr: 6.1035e-08
# Epoch 79/80
# 32/32 [==============================] - ETA: 0s - loss: 5.0087
# Epoch 00079: val_loss did not improve from 3.84352
# 32/32 [==============================] - 3s 107ms/step - loss: 5.0087 - val_loss: 36.4396 - lr: 3.0518e-08
# Epoch 80/80
# 32/32 [==============================] - ETA: 0s - loss: 4.3993
# Epoch 00080: val_loss did not improve from 3.84352
# 32/32 [==============================] - 4s 110ms/step - loss: 4.3993 - val_loss: 29.5710 - lr: 3.0518e-08
# Training Complete!!!

# %% [markdown]
# # Save Model History

# %%
# convert the history.history dict to a pandas DataFrame:     
hist_df = pd.DataFrame(history.history) 

# save to json:  
hist_json_file = 'EffNet_b2_80_epoch_history.json' 
with open(hist_json_file, mode='w') as f:
    hist_df.to_json(f)

# or save to csv: 
hist_csv_file = 'EffNet_b2_80_epoch_history.csv'
with open(hist_csv_file, mode='w') as f:
    hist_df.to_csv(f)

# %% [markdown]
# # Visualize Training Results

# %%
result_dir = 'C:/Users/Monir/Documents/CSE499/results_and_figures/EfficientNet/B2/'

import tikzplotlib
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs_range = range(EPOCHS)

# %%
plt.plot(epochs_range, loss, 'bo', label='Training Loss')
plt.plot(epochs_range, val_loss, 'b', label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend(loc='upper right')

plt.savefig(result_dir + 'b2_80_epoch_oss.png')
plt.savefig(result_dir + 'b2_80_epoch_loss.pdf', dpi=150)
tikzplotlib.save(result_dir + 'b2_80_epoch_loss.tex')

plt.show()

# %%
def smooth_curve(points, factor=0.8):
    smoothed_points = []
    for point in points:
        if smoothed_points:
            previous = smoothed_points[-1]
            smoothed_points.append(previous * factor + point * (1 - factor))
        else:
            smoothed_points.append(point)
    return smoothed_points

# %%
epochs_range = range(10,EPOCHS)

plt.plot(epochs_range,
         smooth_curve(loss[10:]), 'bo', label='Training loss')
plt.plot(epochs_range,
         smooth_curve(val_loss[10:]), 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()


plt.savefig(result_dir + 'b2_80_epoch_loss_smooth.png')
plt.savefig(result_dir + 'b2_80_epoch_smooth.pdf', dpi=150)
tikzplotlib.save(result_dir + 'b2_80_epoch_smooth.tex')

plt.show()
